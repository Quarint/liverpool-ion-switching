# %%
import pandas as pd
import os
import matplotlib.pyplot as plt

# %%
data_folder = "../data"
train_file = os.path.join(data_folder, "train_clean.csv")

# %%
all_data = pd.read_csv(train_file)

# %%
all_data.head()
# Out:
#      time  signal  open_channels
# 0  0.0001 -2.7600              0
# 1  0.0002 -2.8557              0
# 2  0.0003 -2.4074              0
# 3  0.0004 -3.1404              0
# 4  0.0005 -3.1525              0

# %%
fig, ax = plt.subplots(2, 1, figsize=(14, 8))
ax[0].plot(all_data["time"], all_data["signal"])
ax[1].plot(all_data["time"], all_data["open_channels"])

# %% [markdown]
# # K-fold cross validation
#
# Cross validation for timeseries data is tricky. You cannot train a model on some given data and then test it on later data, because
